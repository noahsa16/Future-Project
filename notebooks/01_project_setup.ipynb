# %% [markdown]
# # Project Setup
#
# Use this notebook to document the first setup steps of your project.
#
# Suggested tasks:
# - load the dataset
# - inspect columns
# - check shape and missing values
# - write first observations
